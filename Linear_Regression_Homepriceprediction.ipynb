# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pwd
# Out:
# 'F:\\neel\\fingertips\\machine learning'

# %%
import os
os.chdir('F:\\neel\\fingertips\\machine learning')

# %%
data = pd.read_csv('Python_Linear_Regres (1).csv')

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
data.Suburb.unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
# ...

# %%
import numpy as np
#number of unique value in columns
data.Suburb.unique().size
# Out:
# 351

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
corr =data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#drop columns that have less important
data.drop([])
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
sns.scatterplot(x=data['Propertycount'],y=data['Price'])
# Out:
# <AxesSubplot:xlabel='Propertycount', ylabel='Price'>

# %%
sns.scatterplot(x=data['YearBuilt'],y=data['Price'])
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='Price'>

# %%
data= data.drop(['Address','Date','Postcode','YearBuilt','Lattitude','Longtitude'],axis=1)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data['Bathroom'].value_counts()
# Out:
# 1.0     12969
# 2.0     11064
# 3.0      2181
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 12.0        1
# 9.0         1
# Name: Bathroom, dtype: int64

# %%
data['Bathroom'].fillna(value=1,inplace=True)
data['Bathroom'].isnull().sum()
# Out:
# 0

# %%
data['Distance'].fillna(value=0,inplace=True)
data['Distance'].isnull().sum()
# Out:
# 0

# %%
data['Bedroom2'].value_counts()
# Out:
# 3.0     11881
# 4.0      6348
# 2.0      5777
# 5.0      1427
# 1.0       966
# 6.0       168
# 7.0        30
# 0.0        17
# 8.0        13
# 9.0         5
# 10.0        4
# 30.0        1
# 20.0        1
# 16.0        1
# 12.0        1
# Name: Bedroom2, dtype: int64

# %%
data['Bedroom2'].fillna(value=0,inplace=True)
data['Bedroom2'].isnull().sum()
# Out:
# 0

# %%
data['Propertycount'].fillna(value=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
data['Car'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  6.,  5.,  4.,  3.,  8.,  7., 11., 26.,  9.,
#        10., 18., 12.])

# %%
data['Car'].fillna(value=0,inplace=True)

# %%
data.dropna(subset=['CouncilArea','Regionname'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11807
# BuildingArea     21112
# CouncilArea          0
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
data['Landsize'].fillna(value=data['Landsize'].mean(),inplace=True)

# %%
data['BuildingArea'].fillna(value=data['BuildingArea'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34854 entries, 0 to 34856
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34854 non-null  object
#  1   Rooms          34854 non-null  int64
#  2   Type           34854 non-null  object
#  3   Price          27244 non-null  float64
#  4   Method         34854 non-null  object
#  5   SellerG        34854 non-null  object
#  6   Distance       34854 non-null  float64
#  7   Bedroom2       34854 non-null  float64
#  8   Bathroom       34854 non-null  float64
#  9   Car            34854 non-null  float64
#  10  Landsize       34854 non-null  float64
#  11  BuildingArea   34854 non-null  float64
#  12  CouncilArea    34854 non-null  object
#  13  Regionname     34854 non-null  object
#  14  Propertycount  34854 non-null  float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 4.3+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27244 entries, 1 to 34856
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27244 non-null  object
#  1   Rooms          27244 non-null  int64
#  2   Type           27244 non-null  object
#  3   Price          27244 non-null  float64
#  4   Method         27244 non-null  object
#  5   SellerG        27244 non-null  object
#  6   Distance       27244 non-null  float64
#  7   Bedroom2       27244 non-null  float64
#  8   Bathroom       27244 non-null  float64
#  9   Car            27244 non-null  float64
#  10  Landsize       27244 non-null  float64
#  11  BuildingArea   27244 non-null  float64
#  12  CouncilArea    27244 non-null  object
#  13  Regionname     27244 non-null  object
#  14  Propertycount  27244 non-null  float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
data['Type'].unique()
# Out:
# array(['h', 't', 'u'], dtype=object)

# %%
data['SellerG'].unique()
# Out:
# array(['Biggin', 'Nelson', 'Jellis', 'Dingle', 'Purplebricks', 'Greg',
#        'LITTLE', 'Collins', 'Kay', 'Beller', 'Marshall', 'hockingstuart',
#        'Brad', 'Maddison', 'Barry', 'Airport', 'Considine', 'Rendina',
#        'Ray', 'Propertyau', 'McDonald', 'Frank', 'Prof.', 'Harcourts',
#        'Thomson', 'Buxton', 'RT', "Sotheby's", 'Cayzer', 'Chisholm',
#        'Brace', 'Miles', 'Holland', 'McGrath', 'Love', 'Thomas', 'Barlow',
#        'Sweeney', 'Village', 'Jas', 'Williams', 'Gunn&Co', 'Burnham',
#        'Compton', 'FN', 'Hunter', 'Raine&Horne', 'Noel', 'Hodges', 'Gary',
#        'Fletchers', 'Woodards', 'Raine', 'Alexkarbon', 'Walshe', 'Weda',
#        'Stockdale', 'Tim', 'AIME', 'Moonee', 'HAR', 'Edward', 'Philip',
#        'RW', 'North', 'MICM', 'Ascend', 'Christopher', 'Morrison',
#        'Mandy', 'R&H', 'Fletchers/One', 'Lindellas', 'Appleby', 'Assisi',
#        'One', 'Owen', 'Parkes', 'C21', "O'Brien", 'Bayside', 'Paul',
# ...

# %%
data['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
data.drop(['Method','SellerG','Type'],axis='columns')
# Out:
#            Suburb  Rooms      Price  Distance  Bedroom2  Bathroom  Car  \
# 1      Abbotsford      2  1480000.0       2.5       2.0       1.0  1.0
# 2      Abbotsford      2  1035000.0       2.5       2.0       1.0  0.0
# 4      Abbotsford      3  1465000.0       2.5       3.0       2.0  0.0
# 5      Abbotsford      3   850000.0       2.5       3.0       2.0  1.0
# 6      Abbotsford      4  1600000.0       2.5       3.0       1.0  2.0
# ...           ...    ...        ...       ...       ...       ...  ...
# 34852  Yarraville      4  1480000.0       6.3       4.0       1.0  3.0
# 34853  Yarraville      2   888000.0       6.3       2.0       2.0  1.0
# 34854  Yarraville      2   705000.0       6.3       2.0       1.0  2.0
# 34855  Yarraville      3  1140000.0       6.3       0.0       1.0  0.0
# 34856  Yarraville      2  1020000.0       6.3       2.0       1.0  0.0
#
#          Landsize  BuildingArea               CouncilArea  \
# ...

# %%
data = pd.get_dummies(data)
data
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1          2  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2          2  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 4          3  1465000.0       2.5       3.0       2.0  0.0  134.000000
# 5          3   850000.0       2.5       3.0       2.0  1.0   94.000000
# 6          4  1600000.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852      4  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3  1140000.0       6.3       0.0       1.0  0.0  593.598993
# 34856      2  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Propertycount  Suburb_Abbotsford  ...  \
# ...

# %%
x= data.drop('Price',axis=1)
y=data['Price']

# %%
x
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# 1          2       2.5       2.0       1.0  1.0  202.000000      160.2564
# 2          2       2.5       2.0       1.0  0.0  156.000000       79.0000
# 4          3       2.5       3.0       2.0  0.0  134.000000      150.0000
# 5          3       2.5       3.0       2.0  1.0   94.000000      160.2564
# 6          4       2.5       3.0       1.0  2.0  120.000000      142.0000
# ...      ...       ...       ...       ...  ...         ...           ...
# 34852      4       6.3       4.0       1.0  3.0  593.000000      160.2564
# 34853      2       6.3       2.0       2.0  1.0   98.000000      104.0000
# 34854      2       6.3       2.0       1.0  2.0  220.000000      120.0000
# 34855      3       6.3       0.0       1.0  0.0  593.598993      160.2564
# 34856      2       6.3       2.0       1.0  0.0  250.000000      103.0000
#
#        Propertycount  Suburb_Abbotsford  Suburb_Aberfeldie  ...  \
# ...

# %%
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
#split data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.6811519025352739

# %%
model.score(x_test,y_test)
# Out:
# 0.6770090978667518

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([1499410.17323621,  125587.95717366, 2155974.37434676, ...,
#         553640.97771003, 1613909.38725916, 1678291.68930625])

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2 = r2_score(y_test,y_predict)

# %%
r2
# Out:
# 0.6770090978667518

# %%
mse = mean_squared_error(y_test,y_predict)
mse
# Out:
# 137367903724.10616

# %%
#model accuracy is 
data['Propertycount'].hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import chi2,f_regression
from sklearn.feature_selection import SelectKBest

# %%
bestfeature = SelectKBest(score_func=chi2,k=5)

# %%
features = bestfeature.fit(x, y)

# %%
datascore = pd.DataFrame(features.scores_)
dfcolumns=pd.DataFrame(x.columns)

# %%
datascore
# Out:
#                 0
# 0     3133.692154
# 1    17916.796445
# 2     6011.762848
# 3     2244.798522
# 4     4097.727869
# ..            ...
# 745   2910.797720
# 746   2851.350550
# 747   4677.714840
# 748   2548.455399
# 749   4317.060159
#
# [750 rows x 1 columns]
